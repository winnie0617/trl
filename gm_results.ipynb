# %%
import pandas as pd

df = pd.read_csv("/home/winnie/trl/PPOVanilla_newRM0.9999_testFalse_num0_26_8bit_tmp.csv", index_col=0)
df.mean().values

my_df = pd.read_csv("/home/winnie/trl/wandb_export_2023-07-30T20_31_29.899+08_00.csv", index_col=0)
import matplotlib.pyplot as plt
gold = df.mean().values
my_rm = my_df["Incomplete sentences - ppo/returns/mean"].values
plt.plot(range(len(gold)), gold)
plt.plot(range(len(my_rm)), my_rm)
# Out:
# /tmp/ipykernel_800780/2999697426.py:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean().values
# /tmp/ipykernel_800780/2999697426.py:8: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   gold = df.mean().values
