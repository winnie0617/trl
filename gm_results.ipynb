# %%
import pandas as pd

df = pd.read_csv("/home/winnie/trl/PPOVanilla_newRM0.9999_testFalse_num0_26_8bit_tmp.csv", index_col=0)
df.mean().values

my_df = pd.read_csv("/home/winnie/trl/wandb_export_2023-07-30T20_31_29.899+08_00.csv", index_col=0)
import matplotlib.pyplot as plt
gold = df.mean().values[1:]
my_rm = my_df["Incomplete sentences - ppo/returns/mean"].values
# plt.plot(range(len(gold)), gold)
# plt.plot(range(len(my_rm)), my_rm)
import numpy as np
import matplotlib.pyplot as plt
x = range(len(gold))
y1 = gold
y2 = my_rm

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(x, y1, 'g-')
ax2.plot(x, y2, 'b-')

ax1.set_xlabel('X data')
ax1.set_ylabel('Gold Score', color='g')
ax2.set_ylabel('Proxy Score', color='b')

plt.show()
# Out:
# /tmp/ipykernel_1856602/114695725.py:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean().values
# /tmp/ipykernel_1856602/114695725.py:8: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   gold = df.mean().values[1:]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 x = range(len(gold))
#       4 y1 = gold
#       5 y2 = my_rm
#
# NameError: name 'gold' is not defined
